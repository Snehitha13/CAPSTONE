# %% [markdown]
# <a href="https://colab.research.google.com/github/Snehitha13/CAPSTONE/blob/main/LSTM_MSFT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# dataset @ https://finance.yahoo.com/quote/MSFT/history/

# %%
 import pandas as pd

df = pd.read_csv('MSFT.csv')

df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     1986-03-13    0.088542    0.101563    0.088542    0.097222    0.060657
# 1     1986-03-14    0.097222    0.102431    0.097222    0.100694    0.062823
# 2     1986-03-17    0.100694    0.103299    0.100694    0.102431    0.063907
# 3     1986-03-18    0.102431    0.103299    0.098958    0.099826    0.062281
# 4     1986-03-19    0.099826    0.100694    0.097222    0.098090    0.061198
# ...          ...         ...         ...         ...         ...         ...
# 9359  2023-05-02  307.760010  309.179993  303.910004  305.410004  305.410004
# 9360  2023-05-03  306.619995  308.609985  304.089996  304.399994  304.399994
# 9361  2023-05-04  306.239990  307.760010  303.399994  305.410004  305.410004
# 9362  2023-05-05  305.720001  311.970001  304.269989  310.649994  310.649994
# 9363  2023-05-08  310.130005  310.200012  306.089996  308.649994  308.649994
#
#           Volume
# 0     1031788800
# 1      308160000
# 2      133171200
# 3       67766400
# 4       47894400
# ...          ...
# 9359    26404400
# 9360    22360800
# 9361    22519900
# 9362    28181200
# 9363    21306900
#
# [9364 rows x 7 columns]

# %%
df = df[['Date', 'Close']]

df
# Out:
#             Date       Close
# 0     1986-03-13    0.097222
# 1     1986-03-14    0.100694
# 2     1986-03-17    0.102431
# 3     1986-03-18    0.099826
# 4     1986-03-19    0.098090
# ...          ...         ...
# 9359  2023-05-02  305.410004
# 9360  2023-05-03  304.399994
# 9361  2023-05-04  305.410004
# 9362  2023-05-05  310.649994
# 9363  2023-05-08  308.649994
#
# [9364 rows x 2 columns]

# %%
df['Date']
# Out:
# 0       1986-03-13
# 1       1986-03-14
# 2       1986-03-17
# 3       1986-03-18
# 4       1986-03-19
#            ...
# 9359    2023-05-02
# 9360    2023-05-03
# 9361    2023-05-04
# 9362    2023-05-05
# 9363    2023-05-08
# Name: Date, Length: 9364, dtype: object

# %%
import datetime

def str_to_datetime(s):
  split = s.split('-')
  year, month, day = int(split[0]), int(split[1]), int(split[2])
  return datetime.datetime(year=year, month=month, day=day)

datetime_object = str_to_datetime('1986-03-19')
datetime_object
# Out:
# datetime.datetime(1986, 3, 19, 0, 0)

# %%
df
# Out:
#             Date       Close
# 0     1986-03-13    0.097222
# 1     1986-03-14    0.100694
# 2     1986-03-17    0.102431
# 3     1986-03-18    0.099826
# 4     1986-03-19    0.098090
# ...          ...         ...
# 9359  2023-05-02  305.410004
# 9360  2023-05-03  304.399994
# 9361  2023-05-04  305.410004
# 9362  2023-05-05  310.649994
# 9363  2023-05-08  308.649994
#
# [9364 rows x 2 columns]

# %%
df['Date'] = df['Date'].apply(str_to_datetime)
df['Date']
# Out:
# <ipython-input-6-f6fc52bb0fa5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date'] = df['Date'].apply(str_to_datetime)
# 0      1986-03-13
# 1      1986-03-14
# 2      1986-03-17
# 3      1986-03-18
# 4      1986-03-19
#           ...
# 9359   2023-05-02
# 9360   2023-05-03
# 9361   2023-05-04
# 9362   2023-05-05
# 9363   2023-05-08
# Name: Date, Length: 9364, dtype: datetime64[ns]

# %%
df.index = df.pop('Date')

# %%
import matplotlib.pyplot as plt

plt.plot(df.index, df['Close'])

# %%
import numpy as np

def df_to_windowed_df(dataframe, first_date_str, last_date_str, n=3):
  first_date = str_to_datetime(first_date_str)
  last_date  = str_to_datetime(last_date_str)

  target_date = first_date

  dates = []
  X, Y = [], []

  last_time = False
  while True:
    df_subset = dataframe.loc[:target_date].tail(n+1)

    if len(df_subset) != n+1:
      print(f'Error: Window of size {n} is too large for date {target_date}')
      return

    values = df_subset['Close'].to_numpy()
    x, y = values[:-1], values[-1]

    dates.append(target_date)
    X.append(x)
    Y.append(y)

    next_week = dataframe.loc[target_date:target_date+datetime.timedelta(days=7)]
    next_datetime_str = str(next_week.head(2).tail(1).index.values[0])
    next_date_str = next_datetime_str.split('T')[0]
    year_month_day = next_date_str.split('-')
    year, month, day = year_month_day
    next_date = datetime.datetime(day=int(day), month=int(month), year=int(year))

    if last_time:
      break

    target_date = next_date

    if target_date == last_date:
      last_time = True

  ret_df = pd.DataFrame({})
  ret_df['Target Date'] = dates

  X = np.array(X)
  for i in range(0, n):
    X[:, i]
    ret_df[f'Target-{n-i}'] = X[:, i]

  ret_df['Target'] = Y

  return ret_df

# Start day second time around: '2021-03-25'
windowed_df = df_to_windowed_df(df,
                                '2021-03-25',
                                '2022-03-23',
                                n=3)
windowed_df
# Out:
#     Target Date    Target-3    Target-2    Target-1      Target
# 0    2021-03-25  235.990005  237.580002  235.460007  232.339996
# 1    2021-03-26  237.580002  235.460007  232.339996  236.479996
# 2    2021-03-29  235.460007  232.339996  236.479996  235.240005
# 3    2021-03-30  232.339996  236.479996  235.240005  231.850006
# 4    2021-03-31  236.479996  235.240005  231.850006  235.770004
# ..          ...         ...         ...         ...         ...
# 247  2022-03-17  276.440002  287.149994  294.390015  295.220001
# 248  2022-03-18  287.149994  294.390015  295.220001  300.429993
# 249  2022-03-21  294.390015  295.220001  300.429993  299.160004
# 250  2022-03-22  295.220001  300.429993  299.160004  304.059998
# 251  2022-03-23  300.429993  299.160004  304.059998  299.489990
#
# [252 rows x 5 columns]

# %%
def windowed_df_to_date_X_y(windowed_dataframe):
  df_as_np = windowed_dataframe.to_numpy()

  dates = df_as_np[:, 0]

  middle_matrix = df_as_np[:, 1:-1]
  X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))

  Y = df_as_np[:, -1]

  return dates, X.astype(np.float32), Y.astype(np.float32)

dates, X, y = windowed_df_to_date_X_y(windowed_df)

dates.shape, X.shape, y.shape
# Out:
# ((252,), (252, 3, 1), (252,))

# %%
q_80 = int(len(dates) * .8)
q_90 = int(len(dates) * .9)

dates_train, X_train, y_train = dates[:q_80], X[:q_80], y[:q_80]

dates_val, X_val, y_val = dates[q_80:q_90], X[q_80:q_90], y[q_80:q_90]
dates_test, X_test, y_test = dates[q_90:], X[q_90:], y[q_90:]

plt.plot(dates_train, y_train)
plt.plot(dates_val, y_val)
plt.plot(dates_test, y_test)

plt.legend(['Train', 'Validation', 'Test'])

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers

model = Sequential([layers.Input((3, 1)),
                    layers.LSTM(64),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(1)])

model.compile(loss='mse',
              optimizer=Adam(learning_rate=0.001),
              metrics=['mean_absolute_error'])

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 3s 99ms/step - loss: 84392.8281 - mean_absolute_error: 288.7598 - val_loss: 92029.5078 - val_mean_absolute_error: 303.2763
# Epoch 2/100
# 7/7 [==============================] - 0s 8ms/step - loss: 84066.5078 - mean_absolute_error: 288.1936 - val_loss: 91580.7188 - val_mean_absolute_error: 302.5355
# Epoch 3/100
# 7/7 [==============================] - 0s 8ms/step - loss: 83581.8594 - mean_absolute_error: 287.3546 - val_loss: 91034.3203 - val_mean_absolute_error: 301.6312
# Epoch 4/100
# 7/7 [==============================] - 0s 8ms/step - loss: 83027.6953 - mean_absolute_error: 286.3892 - val_loss: 90364.3516 - val_mean_absolute_error: 300.5185
# Epoch 5/100
# 7/7 [==============================] - 0s 12ms/step - loss: 82314.9766 - mean_absolute_error: 285.1382 - val_loss: 89456.5469 - val_mean_absolute_error: 299.0043
# Epoch 6/100
# 7/7 [==============================] - 0s 8ms/step - loss: 81367.3594 - mean_absolute_error: 283.4781 - val_loss: 88357.0078 - val_mean_absolute_error: 297.1599
# Epoch 7/100
# 7/7 [==============================] - 0s 9ms/step - loss: 80243.6328 - mean_absolute_error: 281.4765 - val_loss: 86966.0938 - val_mean_absolute_error: 294.8102
# Epoch 8/100
# 7/7 [==============================] - 0s 8ms/step - loss: 78721.9609 - mean_absolute_error: 278.7478 - val_loss: 84966.0703 - val_mean_absolute_error: 291.3983
# Epoch 9/100
# 7/7 [==============================] - 0s 8ms/step - loss: 76498.7656 - mean_absolute_error: 274.7336 - val_loss: 81960.5625 - val_mean_absolute_error: 286.1946
# Epoch 10/100
# 7/7 [==============================] - 0s 9ms/step - loss: 73221.7734 - mean_absolute_error: 268.6841 - val_loss: 77906.5469 - val_mean_absolute_error: 279.0221
# Epoch 11/100
# 7/7 [==============================] - 0s 8ms/step - loss: 69055.6797 - mean_absolute_error: 260.8576 - val_loss: 73152.2812 - val_mean_absolute_error: 270.3687
# Epoch 12/100
# 7/7 [==============================] - 0s 8ms/step - loss: 64477.2539 - mean_absolute_error: 251.9245 - val_loss: 67969.1875 - val_mean_absolute_error: 260.6074
# Epoch 13/100
# 7/7 [==============================] - 0s 8ms/step - loss: 59479.7422 - mean_absolute_error: 241.8007 - val_loss: 62471.7305 - val_mean_absolute_error: 249.8374
# Epoch 14/100
# 7/7 [==============================] - 0s 8ms/step - loss: 54118.7656 - mean_absolute_error: 230.4113 - val_loss: 56367.4492 - val_mean_absolute_error: 237.3064
# Epoch 15/100
# 7/7 [==============================] - 0s 9ms/step - loss: 48008.0430 - mean_absolute_error: 216.7488 - val_loss: 48939.9805 - val_mean_absolute_error: 221.1033
# Epoch 16/100
# 7/7 [==============================] - 0s 9ms/step - loss: 40721.0312 - mean_absolute_error: 199.1213 - val_loss: 41127.2070 - val_mean_absolute_error: 202.6672
# Epoch 17/100
# 7/7 [==============================] - 0s 8ms/step - loss: 33572.2930 - mean_absolute_error: 180.4180 - val_loss: 33580.7539 - val_mean_absolute_error: 183.1056
# Epoch 18/100
# 7/7 [==============================] - 0s 8ms/step - loss: 26790.2266 - mean_absolute_error: 160.6247 - val_loss: 26502.7832 - val_mean_absolute_error: 162.6338
# Epoch 19/100
# 7/7 [==============================] - 0s 9ms/step - loss: 20626.2051 - mean_absolute_error: 139.8356 - val_loss: 20121.2383 - val_mean_absolute_error: 141.6625
# Epoch 20/100
# 7/7 [==============================] - 0s 8ms/step - loss: 15131.1309 - mean_absolute_error: 118.8319 - val_loss: 14564.0225 - val_mean_absolute_error: 120.4614
# Epoch 21/100
# 7/7 [==============================] - 0s 12ms/step - loss: 10401.3564 - mean_absolute_error: 97.0184 - val_loss: 9564.6729 - val_mean_absolute_error: 97.5279
# Epoch 22/100
# 7/7 [==============================] - 0s 9ms/step - loss: 6592.3389 - mean_absolute_error: 74.4265 - val_loss: 5851.5171 - val_mean_absolute_error: 76.1463
# Epoch 23/100
# 7/7 [==============================] - 0s 9ms/step - loss: 3934.9045 - mean_absolute_error: 53.6144 - val_loss: 3229.0220 - val_mean_absolute_error: 56.3565
# Epoch 24/100
# 7/7 [==============================] - 0s 9ms/step - loss: 2256.3765 - mean_absolute_error: 38.4054 - val_loss: 1734.1272 - val_mean_absolute_error: 41.0020
# Epoch 25/100
# 7/7 [==============================] - 0s 8ms/step - loss: 1467.9880 - mean_absolute_error: 31.7234 - val_loss: 897.9788 - val_mean_absolute_error: 29.0691
# Epoch 26/100
# 7/7 [==============================] - 0s 8ms/step - loss: 1132.9539 - mean_absolute_error: 28.4902 - val_loss: 479.5288 - val_mean_absolute_error: 20.6535
# Epoch 27/100
# 7/7 [==============================] - 0s 13ms/step - loss: 1016.7668 - mean_absolute_error: 27.0077 - val_loss: 292.4694 - val_mean_absolute_error: 15.4957
# Epoch 28/100
# 7/7 [==============================] - 0s 14ms/step - loss: 1011.7974 - mean_absolute_error: 26.8847 - val_loss: 216.1676 - val_mean_absolute_error: 13.0109
# Epoch 29/100
# 7/7 [==============================] - 0s 14ms/step - loss: 1016.0451 - mean_absolute_error: 26.9452 - val_loss: 187.8610 - val_mean_absolute_error: 11.9432
# Epoch 30/100
# 7/7 [==============================] - 0s 15ms/step - loss: 1022.6619 - mean_absolute_error: 27.0002 - val_loss: 182.7845 - val_mean_absolute_error: 11.7402
# Epoch 31/100
# 7/7 [==============================] - 0s 16ms/step - loss: 1019.6125 - mean_absolute_error: 26.9770 - val_loss: 202.1606 - val_mean_absolute_error: 12.4952
# Epoch 32/100
# 7/7 [==============================] - 0s 12ms/step - loss: 1015.0457 - mean_absolute_error: 26.9479 - val_loss: 227.0203 - val_mean_absolute_error: 13.3954
# Epoch 33/100
# 7/7 [==============================] - 0s 15ms/step - loss: 1014.1537 - mean_absolute_error: 26.9162 - val_loss: 255.4369 - val_mean_absolute_error: 14.3490
# Epoch 34/100
# 7/7 [==============================] - 0s 14ms/step - loss: 1005.9189 - mean_absolute_error: 26.8130 - val_loss: 280.2392 - val_mean_absolute_error: 15.1412
# Epoch 35/100
# 7/7 [==============================] - 0s 12ms/step - loss: 1012.5014 - mean_absolute_error: 26.9998 - val_loss: 324.4184 - val_mean_absolute_error: 16.5069
# Epoch 36/100
# 7/7 [==============================] - 0s 15ms/step - loss: 980.2943 - mean_absolute_error: 26.4859 - val_loss: 268.7578 - val_mean_absolute_error: 14.7873
# Epoch 37/100
# 7/7 [==============================] - 0s 15ms/step - loss: 984.5827 - mean_absolute_error: 26.5180 - val_loss: 277.1940 - val_mean_absolute_error: 15.0563
# Epoch 38/100
# 7/7 [==============================] - 0s 12ms/step - loss: 978.3072 - mean_absolute_error: 26.4766 - val_loss: 304.4461 - val_mean_absolute_error: 15.8977
# Epoch 39/100
# 7/7 [==============================] - 0s 13ms/step - loss: 975.5861 - mean_absolute_error: 26.4180 - val_loss: 244.0543 - val_mean_absolute_error: 14.0021
# Epoch 40/100
# 7/7 [==============================] - 0s 12ms/step - loss: 969.7948 - mean_absolute_error: 26.3113 - val_loss: 273.0498 - val_mean_absolute_error: 14.9361
# Epoch 41/100
# 7/7 [==============================] - 0s 11ms/step - loss: 969.3801 - mean_absolute_error: 26.3155 - val_loss: 274.6879 - val_mean_absolute_error: 14.9901
# Epoch 42/100
# 7/7 [==============================] - 0s 12ms/step - loss: 960.0399 - mean_absolute_error: 26.2217 - val_loss: 298.6147 - val_mean_absolute_error: 15.7329
# Epoch 43/100
# 7/7 [==============================] - 0s 11ms/step - loss: 953.3108 - mean_absolute_error: 26.1012 - val_loss: 243.9049 - val_mean_absolute_error: 14.0132
# Epoch 44/100
# 7/7 [==============================] - 0s 14ms/step - loss: 946.1183 - mean_absolute_error: 25.9754 - val_loss: 309.5571 - val_mean_absolute_error: 16.1096
# Epoch 45/100
# 7/7 [==============================] - 0s 12ms/step - loss: 915.2017 - mean_absolute_error: 25.5834 - val_loss: 766.3066 - val_mean_absolute_error: 26.7630
# Epoch 46/100
# 7/7 [==============================] - 0s 12ms/step - loss: 1017.2528 - mean_absolute_error: 26.9556 - val_loss: 220.7361 - val_mean_absolute_error: 13.2560
# Epoch 47/100
# 7/7 [==============================] - 0s 16ms/step - loss: 925.2222 - mean_absolute_error: 25.5938 - val_loss: 277.6453 - val_mean_absolute_error: 15.1495
# Epoch 48/100
# 7/7 [==============================] - 0s 16ms/step - loss: 843.3495 - mean_absolute_error: 24.5548 - val_loss: 395.7047 - val_mean_absolute_error: 18.6898
# Epoch 49/100
# 7/7 [==============================] - 0s 16ms/step - loss: 826.5935 - mean_absolute_error: 24.2122 - val_loss: 969.5168 - val_mean_absolute_error: 30.3701
# Epoch 50/100
# 7/7 [==============================] - 0s 15ms/step - loss: 896.1184 - mean_absolute_error: 24.7582 - val_loss: 249.4640 - val_mean_absolute_error: 14.2935
# Epoch 51/100
# 7/7 [==============================] - 0s 18ms/step - loss: 770.0853 - mean_absolute_error: 23.3221 - val_loss: 226.3164 - val_mean_absolute_error: 13.5670
# Epoch 52/100
# 7/7 [==============================] - 0s 13ms/step - loss: 710.1793 - mean_absolute_error: 22.4872 - val_loss: 442.7627 - val_mean_absolute_error: 20.0075
# Epoch 53/100
# 7/7 [==============================] - 0s 15ms/step - loss: 692.6415 - mean_absolute_error: 22.0613 - val_loss: 265.3316 - val_mean_absolute_error: 14.9475
# Epoch 54/100
# 7/7 [==============================] - 0s 17ms/step - loss: 633.3347 - mean_absolute_error: 21.0967 - val_loss: 198.3719 - val_mean_absolute_error: 12.6617
# Epoch 55/100
# 7/7 [==============================] - 0s 9ms/step - loss: 557.0209 - mean_absolute_error: 19.7522 - val_loss: 187.5521 - val_mean_absolute_error: 12.2842
# Epoch 56/100
# 7/7 [==============================] - 0s 8ms/step - loss: 496.8784 - mean_absolute_error: 18.6327 - val_loss: 281.1566 - val_mean_absolute_error: 15.6360
# Epoch 57/100
# 7/7 [==============================] - 0s 8ms/step - loss: 443.4547 - mean_absolute_error: 17.5118 - val_loss: 161.8945 - val_mean_absolute_error: 11.3281
# Epoch 58/100
# 7/7 [==============================] - 0s 9ms/step - loss: 399.0432 - mean_absolute_error: 16.1711 - val_loss: 97.6619 - val_mean_absolute_error: 8.3199
# Epoch 59/100
# 7/7 [==============================] - 0s 8ms/step - loss: 371.3898 - mean_absolute_error: 15.8152 - val_loss: 153.2044 - val_mean_absolute_error: 11.0128
# Epoch 60/100
# 7/7 [==============================] - 0s 9ms/step - loss: 318.3417 - mean_absolute_error: 14.1610 - val_loss: 94.1867 - val_mean_absolute_error: 8.2097
# Epoch 61/100
# 7/7 [==============================] - 0s 8ms/step - loss: 297.2877 - mean_absolute_error: 13.8081 - val_loss: 36.1085 - val_mean_absolute_error: 5.0286
# Epoch 62/100
# 7/7 [==============================] - 0s 8ms/step - loss: 248.1059 - mean_absolute_error: 12.4924 - val_loss: 74.6695 - val_mean_absolute_error: 7.1211
# Epoch 63/100
# 7/7 [==============================] - 0s 8ms/step - loss: 194.9017 - mean_absolute_error: 10.9628 - val_loss: 50.1527 - val_mean_absolute_error: 5.7233
# Epoch 64/100
# 7/7 [==============================] - 0s 8ms/step - loss: 167.2183 - mean_absolute_error: 10.1127 - val_loss: 80.7672 - val_mean_absolute_error: 7.5084
# Epoch 65/100
# 7/7 [==============================] - 0s 8ms/step - loss: 134.9278 - mean_absolute_error: 8.7973 - val_loss: 33.6470 - val_mean_absolute_error: 5.0316
# Epoch 66/100
# 7/7 [==============================] - 0s 8ms/step - loss: 101.3433 - mean_absolute_error: 7.0420 - val_loss: 30.5416 - val_mean_absolute_error: 4.8667
# Epoch 67/100
# 7/7 [==============================] - 0s 8ms/step - loss: 79.7345 - mean_absolute_error: 6.7003 - val_loss: 43.3794 - val_mean_absolute_error: 5.5421
# Epoch 68/100
# 7/7 [==============================] - 0s 8ms/step - loss: 73.3141 - mean_absolute_error: 6.4543 - val_loss: 37.9060 - val_mean_absolute_error: 5.0288
# Epoch 69/100
# 7/7 [==============================] - 0s 8ms/step - loss: 64.9560 - mean_absolute_error: 6.2367 - val_loss: 77.3681 - val_mean_absolute_error: 7.1281
# Epoch 70/100
# 7/7 [==============================] - 0s 11ms/step - loss: 72.4597 - mean_absolute_error: 6.9143 - val_loss: 129.8635 - val_mean_absolute_error: 9.9649
# Epoch 71/100
# 7/7 [==============================] - 0s 8ms/step - loss: 69.0733 - mean_absolute_error: 6.7615 - val_loss: 76.6211 - val_mean_absolute_error: 7.0968
# Epoch 72/100
# 7/7 [==============================] - 0s 9ms/step - loss: 45.7633 - mean_absolute_error: 5.1214 - val_loss: 34.8083 - val_mean_absolute_error: 4.8985
# Epoch 73/100
# 7/7 [==============================] - 0s 8ms/step - loss: 40.5552 - mean_absolute_error: 4.7672 - val_loss: 35.3037 - val_mean_absolute_error: 4.9034
# Epoch 74/100
# 7/7 [==============================] - 0s 8ms/step - loss: 39.7454 - mean_absolute_error: 4.9479 - val_loss: 64.1977 - val_mean_absolute_error: 6.3516
# Epoch 75/100
# 7/7 [==============================] - 0s 8ms/step - loss: 43.9642 - mean_absolute_error: 5.3630 - val_loss: 45.0072 - val_mean_absolute_error: 5.3747
# Epoch 76/100
# 7/7 [==============================] - 0s 8ms/step - loss: 32.8184 - mean_absolute_error: 4.4587 - val_loss: 99.3241 - val_mean_absolute_error: 8.3603
# Epoch 77/100
# 7/7 [==============================] - 0s 8ms/step - loss: 35.6576 - mean_absolute_error: 4.8532 - val_loss: 73.8961 - val_mean_absolute_error: 6.9059
# Epoch 78/100
# 7/7 [==============================] - 0s 9ms/step - loss: 32.6903 - mean_absolute_error: 4.4643 - val_loss: 42.5812 - val_mean_absolute_error: 5.2475
# Epoch 79/100
# 7/7 [==============================] - 0s 9ms/step - loss: 25.9840 - mean_absolute_error: 3.9499 - val_loss: 89.7102 - val_mean_absolute_error: 7.8426
# Epoch 80/100
# 7/7 [==============================] - 0s 8ms/step - loss: 27.4187 - mean_absolute_error: 4.1553 - val_loss: 37.5373 - val_mean_absolute_error: 4.9318
# Epoch 81/100
# 7/7 [==============================] - 0s 9ms/step - loss: 24.9420 - mean_absolute_error: 3.8639 - val_loss: 44.2087 - val_mean_absolute_error: 5.3838
# Epoch 82/100
# 7/7 [==============================] - 0s 9ms/step - loss: 24.1757 - mean_absolute_error: 3.8678 - val_loss: 40.8027 - val_mean_absolute_error: 5.1609
# Epoch 83/100
# 7/7 [==============================] - 0s 8ms/step - loss: 27.3829 - mean_absolute_error: 4.1095 - val_loss: 35.4610 - val_mean_absolute_error: 4.8448
# Epoch 84/100
# 7/7 [==============================] - 0s 9ms/step - loss: 30.3346 - mean_absolute_error: 4.3381 - val_loss: 48.9979 - val_mean_absolute_error: 5.6635
# Epoch 85/100
# 7/7 [==============================] - 0s 9ms/step - loss: 31.1842 - mean_absolute_error: 4.5113 - val_loss: 90.3517 - val_mean_absolute_error: 7.8890
# Epoch 86/100
# 7/7 [==============================] - 0s 10ms/step - loss: 35.6262 - mean_absolute_error: 4.8788 - val_loss: 57.9083 - val_mean_absolute_error: 6.0914
# Epoch 87/100
# 7/7 [==============================] - 0s 9ms/step - loss: 19.7502 - mean_absolute_error: 3.4657 - val_loss: 32.6516 - val_mean_absolute_error: 4.7398
# Epoch 88/100
# 7/7 [==============================] - 0s 9ms/step - loss: 24.4805 - mean_absolute_error: 4.0665 - val_loss: 52.0639 - val_mean_absolute_error: 6.1014
# Epoch 89/100
# 7/7 [==============================] - 0s 8ms/step - loss: 39.9839 - mean_absolute_error: 5.1190 - val_loss: 33.5496 - val_mean_absolute_error: 4.7804
# Epoch 90/100
# 7/7 [==============================] - 0s 9ms/step - loss: 20.8661 - mean_absolute_error: 3.6813 - val_loss: 37.4939 - val_mean_absolute_error: 4.9221
# Epoch 91/100
# 7/7 [==============================] - 0s 8ms/step - loss: 20.2618 - mean_absolute_error: 3.5873 - val_loss: 40.6207 - val_mean_absolute_error: 5.1426
# Epoch 92/100
# 7/7 [==============================] - 0s 8ms/step - loss: 19.5033 - mean_absolute_error: 3.5008 - val_loss: 34.3490 - val_mean_absolute_error: 4.7972
# Epoch 93/100
# 7/7 [==============================] - 0s 8ms/step - loss: 31.3432 - mean_absolute_error: 4.6331 - val_loss: 33.6981 - val_mean_absolute_error: 4.7775
# Epoch 94/100
# 7/7 [==============================] - 0s 8ms/step - loss: 21.3450 - mean_absolute_error: 3.6869 - val_loss: 40.0943 - val_mean_absolute_error: 5.1146
# Epoch 95/100
# 7/7 [==============================] - 0s 8ms/step - loss: 18.2022 - mean_absolute_error: 3.3857 - val_loss: 49.8288 - val_mean_absolute_error: 5.7286
# Epoch 96/100
# 7/7 [==============================] - 0s 8ms/step - loss: 19.1861 - mean_absolute_error: 3.4155 - val_loss: 92.5336 - val_mean_absolute_error: 7.9974
# Epoch 97/100
# 7/7 [==============================] - 0s 8ms/step - loss: 25.0387 - mean_absolute_error: 3.9132 - val_loss: 108.8616 - val_mean_absolute_error: 8.8497
# Epoch 98/100
# 7/7 [==============================] - 0s 9ms/step - loss: 27.0441 - mean_absolute_error: 4.1346 - val_loss: 63.7700 - val_mean_absolute_error: 6.4919
# Epoch 99/100
# 7/7 [==============================] - 0s 9ms/step - loss: 18.9439 - mean_absolute_error: 3.4107 - val_loss: 56.8917 - val_mean_absolute_error: 6.0809
# Epoch 100/100
# 7/7 [==============================] - 0s 29ms/step - loss: 19.5127 - mean_absolute_error: 3.4596 - val_loss: 64.5780 - val_mean_absolute_error: 6.5225

# %%
train_predictions = model.predict(X_train).flatten()

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 7/7 [==============================] - 1s 3ms/step

# %%
val_predictions = model.predict(X_val).flatten()

plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.legend(['Validation Predictions', 'Validation Observations'])
# Out:
# 1/1 [==============================] - 0s 21ms/step

# %%
test_predictions = model.predict(X_test).flatten()

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Testing Predictions', 'Testing Observations'])
# Out:
# 1/1 [==============================] - 0s 36ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Training Predictions',
            'Training Observations',
            'Validation Predictions',
            'Validation Observations',
            'Testing Predictions',
            'Testing Observations'])

# %%
from copy import deepcopy

recursive_predictions = []
recursive_dates = np.concatenate([dates_val, dates_test])

for target_date in recursive_dates:
  last_window = deepcopy(X_train[-1])
  next_prediction = model.predict(np.array([last_window])).flatten()
  recursive_predictions.append(next_prediction)
  last_window[-1] = next_prediction
# Out:
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.plot(recursive_dates, recursive_predictions)
plt.legend(['Training Predictions',
            'Training Observations',
            'Validation Predictions',
            'Validation Observations',
            'Testing Predictions',
            'Testing Observations',
            'Recursive Predictions'])
